# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Series

# %%
data = {
    'Name': 'taro',
    'Date': 20220114,
    'Task': 'math'
}

# %%
pd.Series(data)
# Out:
# Name        taro
# Date    20220114
# Task        math
# dtype: object

# %%
df = pd.read_csv('dataset/tmdb_5000_movies.csv')

# %%
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# 1          http://disney.go.com/disneypictures/pirates/     285
# 2           http://www.sonypictures.com/movies/spectre/  206647
# 3                    http://www.thedarkknightrises.com/   49026
# 4                  http://movies.disney.com/john-carter   49529
# ...                                                 ...     ...
# 4798                                                NaN    9367
# 4799                                                NaN   72766
# 4800  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4801                        http://shanghaicalling.com/  126186
# 4802                                                NaN   25975
#
#                                                keywords original_language  \
# 0     [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1     [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2     [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3     [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4     [{"id": 818, "name": "based on novel"}, {"id":...                en
# ...                                                 ...               ...
# 4798  [{"id": 5616, "name": "united states\u2013mexi...                es
# 4799                                                 []                en
# 4800  [{"id": 248, "name": "date"}, {"id": 699, "nam...                en
# 4801                                                 []                en
# 4802  [{"id": 1523, "name": "obsession"}, {"id": 224...                en
#
#                                 original_title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4798                               El Mariachi
# 4799                                 Newlyweds
# 4800                 Signed, Sealed, Delivered
# 4801                          Shanghai Calling
# 4802                         My Date with Drew
#
#                                                overview  popularity  \
# 0     In the 22nd century, a paraplegic Marine is di...  150.437577
# 1     Captain Barbossa, long believed to be dead, ha...  139.082615
# 2     A cryptic message from Bond’s past sends him o...  107.376788
# 3     Following the death of District Attorney Harve...  112.312950
# 4     John Carter is a war-weary, former military ca...   43.926995
# ...                                                 ...         ...
# 4798  El Mariachi just wants to play his guitar and ...   14.269792
# 4799  A newlywed couple's honeymoon is upended by th...    0.642552
# 4800  "Signed, Sealed, Delivered" introduces a dedic...    1.444476
# 4801  When ambitious New York attorney Sam is sent t...    0.857008
# 4802  Ever since the second grade when he first saw ...    1.929883
#
#                                    production_companies  \
# 0     [{"name": "Ingenious Film Partners", "id": 289...
# 1     [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2     [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3     [{"name": "Legendary Pictures", "id": 923}, {"...
# 4           [{"name": "Walt Disney Pictures", "id": 2}]
# ...                                                 ...
# 4798           [{"name": "Columbia Pictures", "id": 5}]
# 4799                                                 []
# 4800  [{"name": "Front Street Pictures", "id": 3958}...
# 4801                                                 []
# 4802  [{"name": "rusty bear entertainment", "id": 87...
#
#                                    production_countries release_date  \
# 0     [{"iso_3166_1": "US", "name": "United States o...   2009-12-10
# 1     [{"iso_3166_1": "US", "name": "United States o...   2007-05-19
# 2     [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26
# 3     [{"iso_3166_1": "US", "name": "United States o...   2012-07-16
# 4     [{"iso_3166_1": "US", "name": "United States o...   2012-03-07
# ...                                                 ...          ...
# 4798  [{"iso_3166_1": "MX", "name": "Mexico"}, {"iso...   1992-09-04
# 4799                                                 []   2011-12-26
# 4800  [{"iso_3166_1": "US", "name": "United States o...   2013-10-13
# 4801  [{"iso_3166_1": "US", "name": "United States o...   2012-05-03
# 4802  [{"iso_3166_1": "US", "name": "United States o...   2005-08-05
#
#          revenue  runtime                                   spoken_languages  \
# 0     2787965087    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 1      961000000    169.0           [{"iso_639_1": "en", "name": "English"}]
# 2      880674609    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...
# 3     1084939099    165.0           [{"iso_639_1": "en", "name": "English"}]
# 4      284139100    132.0           [{"iso_639_1": "en", "name": "English"}]
# ...          ...      ...                                                ...
# 4798     2040920     81.0      [{"iso_639_1": "es", "name": "Espa\u00f1ol"}]
# 4799           0     85.0                                                 []
# 4800           0    120.0           [{"iso_639_1": "en", "name": "English"}]
# 4801           0     98.0           [{"iso_639_1": "en", "name": "English"}]
# 4802           0     90.0           [{"iso_639_1": "en", "name": "English"}]
#
#         status                                            tagline  \
# 0     Released                        Enter the World of Pandora.
# 1     Released     At the end of the world, the adventure begins.
# 2     Released                              A Plan No One Escapes
# 3     Released                                    The Legend Ends
# 4     Released               Lost in our world, found in another.
# ...        ...                                                ...
# 4798  Released  He didn't come looking for trouble, but troubl...
# 4799  Released  A newlywed couple's honeymoon is upended by th...
# 4800  Released                                                NaN
# 4801  Released                           A New Yorker in Shanghai
# 4802  Released                                                NaN
#
#                                          title  vote_average  vote_count
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# 4                                  John Carter           6.1        2124
# ...                                        ...           ...         ...
# 4798                               El Mariachi           6.6         238
# 4799                                 Newlyweds           5.9           5
# 4800                 Signed, Sealed, Delivered           7.0           6
# 4801                          Shanghai Calling           5.7           7
# 4802                         My Date with Drew           6.3          16
#
# [4803 rows x 20 columns]

# %%
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# 1          http://disney.go.com/disneypictures/pirates/     285
# 2           http://www.sonypictures.com/movies/spectre/  206647
# 3                    http://www.thedarkknightrises.com/   49026
# 4                  http://movies.disney.com/john-carter   49529
# ...                                                 ...     ...
# 4798                                                NaN    9367
# 4799                                                NaN   72766
# 4800  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4801                        http://shanghaicalling.com/  126186
# 4802                                                NaN   25975
#
#                                                keywords original_language  \
# 0     [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1     [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2     [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3     [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4     [{"id": 818, "name": "based on novel"}, {"id":...                en
# ...                                                 ...               ...
# 4798  [{"id": 5616, "name": "united states\u2013mexi...                es
# 4799                                                 []                en
# 4800  [{"id": 248, "name": "date"}, {"id": 699, "nam...                en
# 4801                                                 []                en
# 4802  [{"id": 1523, "name": "obsession"}, {"id": 224...                en
#
#                                 original_title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4798                               El Mariachi
# 4799                                 Newlyweds
# 4800                 Signed, Sealed, Delivered
# 4801                          Shanghai Calling
# 4802                         My Date with Drew
#
#                                                overview  popularity  \
# 0     In the 22nd century, a paraplegic Marine is di...  150.437577
# 1     Captain Barbossa, long believed to be dead, ha...  139.082615
# 2     A cryptic message from Bond’s past sends him o...  107.376788
# 3     Following the death of District Attorney Harve...  112.312950
# 4     John Carter is a war-weary, former military ca...   43.926995
# ...                                                 ...         ...
# 4798  El Mariachi just wants to play his guitar and ...   14.269792
# 4799  A newlywed couple's honeymoon is upended by th...    0.642552
# 4800  "Signed, Sealed, Delivered" introduces a dedic...    1.444476
# 4801  When ambitious New York attorney Sam is sent t...    0.857008
# 4802  Ever since the second grade when he first saw ...    1.929883
#
#                                    production_companies  \
# 0     [{"name": "Ingenious Film Partners", "id": 289...
# 1     [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2     [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3     [{"name": "Legendary Pictures", "id": 923}, {"...
# 4           [{"name": "Walt Disney Pictures", "id": 2}]
# ...                                                 ...
# 4798           [{"name": "Columbia Pictures", "id": 5}]
# 4799                                                 []
# 4800  [{"name": "Front Street Pictures", "id": 3958}...
# 4801                                                 []
# 4802  [{"name": "rusty bear entertainment", "id": 87...
#
#                                    production_countries release_date  \
# 0     [{"iso_3166_1": "US", "name": "United States o...   2009-12-10
# 1     [{"iso_3166_1": "US", "name": "United States o...   2007-05-19
# 2     [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26
# 3     [{"iso_3166_1": "US", "name": "United States o...   2012-07-16
# 4     [{"iso_3166_1": "US", "name": "United States o...   2012-03-07
# ...                                                 ...          ...
# 4798  [{"iso_3166_1": "MX", "name": "Mexico"}, {"iso...   1992-09-04
# 4799                                                 []   2011-12-26
# 4800  [{"iso_3166_1": "US", "name": "United States o...   2013-10-13
# 4801  [{"iso_3166_1": "US", "name": "United States o...   2012-05-03
# 4802  [{"iso_3166_1": "US", "name": "United States o...   2005-08-05
#
#          revenue  runtime                                   spoken_languages  \
# 0     2787965087    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 1      961000000    169.0           [{"iso_639_1": "en", "name": "English"}]
# 2      880674609    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...
# 3     1084939099    165.0           [{"iso_639_1": "en", "name": "English"}]
# 4      284139100    132.0           [{"iso_639_1": "en", "name": "English"}]
# ...          ...      ...                                                ...
# 4798     2040920     81.0      [{"iso_639_1": "es", "name": "Espa\u00f1ol"}]
# 4799           0     85.0                                                 []
# 4800           0    120.0           [{"iso_639_1": "en", "name": "English"}]
# 4801           0     98.0           [{"iso_639_1": "en", "name": "English"}]
# 4802           0     90.0           [{"iso_639_1": "en", "name": "English"}]
#
#         status                                            tagline  \
# 0     Released                        Enter the World of Pandora.
# 1     Released     At the end of the world, the adventure begins.
# 2     Released                              A Plan No One Escapes
# 3     Released                                    The Legend Ends
# 4     Released               Lost in our world, found in another.
# ...        ...                                                ...
# 4798  Released  He didn't come looking for trouble, but troubl...
# 4799  Released  A newlywed couple's honeymoon is upended by th...
# 4800  Released                                                NaN
# 4801  Released                           A New Yorker in Shanghai
# 4802  Released                                                NaN
#
#                                          title  vote_average  vote_count
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# 4                                  John Carter           6.1        2124
# ...                                        ...           ...         ...
# 4798                               El Mariachi           6.6         238
# 4799                                 Newlyweds           5.9           5
# 4800                 Signed, Sealed, Delivered           7.0           6
# 4801                          Shanghai Calling           5.7           7
# 4802                         My Date with Drew           6.3          16
#
# [4803 rows x 20 columns]

# %%
df.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# max       10.000000  13752.000000

# %%
df.head(3)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26   880674609
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466

# %%
df.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
df['revenue'].head(5)
# Out:
# 0    2787965087
# 1     961000000
# 2     880674609
# 3    1084939099
# 4     284139100
# Name: revenue, dtype: int64

# %%
df.revenue
# Out:
# 0       2787965087
# 1        961000000
# 2        880674609
# 3       1084939099
# 4        284139100
#            ...
# 4798       2040920
# 4799             0
# 4800             0
# 4801             0
# 4802             0
# Name: revenue, Length: 4803, dtype: int64

# %%
df[['revenue', 'original_title']]
# Out:
#          revenue                            original_title
# 0     2787965087                                    Avatar
# 1      961000000  Pirates of the Caribbean: At World's End
# 2      880674609                                   Spectre
# 3     1084939099                     The Dark Knight Rises
# 4      284139100                               John Carter
# ...          ...                                       ...
# 4798     2040920                               El Mariachi
# 4799           0                                 Newlyweds
# 4800           0                 Signed, Sealed, Delivered
# 4801           0                          Shanghai Calling
# 4802           0                         My Date with Drew
#
# [4803 rows x 2 columns]

# %%
df.iloc[10:13]['original_title']
# Out:
# 10                              Superman Returns
# 11                             Quantum of Solace
# 12    Pirates of the Caribbean: Dead Man's Chest
# Name: original_title, dtype: object

# %%
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# 1          http://disney.go.com/disneypictures/pirates/     285
# 2           http://www.sonypictures.com/movies/spectre/  206647
# 3                    http://www.thedarkknightrises.com/   49026
# 4                  http://movies.disney.com/john-carter   49529
# ...                                                 ...     ...
# 4798                                                NaN    9367
# 4799                                                NaN   72766
# 4800  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4801                        http://shanghaicalling.com/  126186
# 4802                                                NaN   25975
#
#                                                keywords original_language  \
# 0     [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1     [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2     [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3     [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4     [{"id": 818, "name": "based on novel"}, {"id":...                en
# ...                                                 ...               ...
# 4798  [{"id": 5616, "name": "united states\u2013mexi...                es
# 4799                                                 []                en
# 4800  [{"id": 248, "name": "date"}, {"id": 699, "nam...                en
# 4801                                                 []                en
# 4802  [{"id": 1523, "name": "obsession"}, {"id": 224...                en
#
#                                 original_title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4798                               El Mariachi
# 4799                                 Newlyweds
# 4800                 Signed, Sealed, Delivered
# 4801                          Shanghai Calling
# 4802                         My Date with Drew
#
#                                                overview  popularity  \
# 0     In the 22nd century, a paraplegic Marine is di...  150.437577
# 1     Captain Barbossa, long believed to be dead, ha...  139.082615
# 2     A cryptic message from Bond’s past sends him o...  107.376788
# 3     Following the death of District Attorney Harve...  112.312950
# 4     John Carter is a war-weary, former military ca...   43.926995
# ...                                                 ...         ...
# 4798  El Mariachi just wants to play his guitar and ...   14.269792
# 4799  A newlywed couple's honeymoon is upended by th...    0.642552
# 4800  "Signed, Sealed, Delivered" introduces a dedic...    1.444476
# 4801  When ambitious New York attorney Sam is sent t...    0.857008
# 4802  Ever since the second grade when he first saw ...    1.929883
#
#                                    production_companies  \
# 0     [{"name": "Ingenious Film Partners", "id": 289...
# 1     [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2     [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3     [{"name": "Legendary Pictures", "id": 923}, {"...
# 4           [{"name": "Walt Disney Pictures", "id": 2}]
# ...                                                 ...
# 4798           [{"name": "Columbia Pictures", "id": 5}]
# 4799                                                 []
# 4800  [{"name": "Front Street Pictures", "id": 3958}...
# 4801                                                 []
# 4802  [{"name": "rusty bear entertainment", "id": 87...
#
#                                    production_countries release_date  \
# 0     [{"iso_3166_1": "US", "name": "United States o...   2009-12-10
# 1     [{"iso_3166_1": "US", "name": "United States o...   2007-05-19
# 2     [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26
# 3     [{"iso_3166_1": "US", "name": "United States o...   2012-07-16
# 4     [{"iso_3166_1": "US", "name": "United States o...   2012-03-07
# ...                                                 ...          ...
# 4798  [{"iso_3166_1": "MX", "name": "Mexico"}, {"iso...   1992-09-04
# 4799                                                 []   2011-12-26
# 4800  [{"iso_3166_1": "US", "name": "United States o...   2013-10-13
# 4801  [{"iso_3166_1": "US", "name": "United States o...   2012-05-03
# 4802  [{"iso_3166_1": "US", "name": "United States o...   2005-08-05
#
#          revenue  runtime                                   spoken_languages  \
# 0     2787965087    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 1      961000000    169.0           [{"iso_639_1": "en", "name": "English"}]
# 2      880674609    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...
# 3     1084939099    165.0           [{"iso_639_1": "en", "name": "English"}]
# 4      284139100    132.0           [{"iso_639_1": "en", "name": "English"}]
# ...          ...      ...                                                ...
# 4798     2040920     81.0      [{"iso_639_1": "es", "name": "Espa\u00f1ol"}]
# 4799           0     85.0                                                 []
# 4800           0    120.0           [{"iso_639_1": "en", "name": "English"}]
# 4801           0     98.0           [{"iso_639_1": "en", "name": "English"}]
# 4802           0     90.0           [{"iso_639_1": "en", "name": "English"}]
#
#         status                                            tagline  \
# 0     Released                        Enter the World of Pandora.
# 1     Released     At the end of the world, the adventure begins.
# 2     Released                              A Plan No One Escapes
# 3     Released                                    The Legend Ends
# 4     Released               Lost in our world, found in another.
# ...        ...                                                ...
# 4798  Released  He didn't come looking for trouble, but troubl...
# 4799  Released  A newlywed couple's honeymoon is upended by th...
# 4800  Released                                                NaN
# 4801  Released                           A New Yorker in Shanghai
# 4802  Released                                                NaN
#
#                                          title  vote_average  vote_count
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# 4                                  John Carter           6.1        2124
# ...                                        ...           ...         ...
# 4798                               El Mariachi           6.6         238
# 4799                                 Newlyweds           5.9           5
# 4800                 Signed, Sealed, Delivered           7.0           6
# 4801                          Shanghai Calling           5.7           7
# 4802                         My Date with Drew           6.3          16
#
# [4803 rows x 20 columns]

# %% [markdown]
# ## .drop()

# %%
df.drop(0)
# Out:
#          budget                                             genres  \
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5     258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 1          http://disney.go.com/disneypictures/pirates/     285
# 2           http://www.sonypictures.com/movies/spectre/  206647
# 3                    http://www.thedarkknightrises.com/   49026
# 4                  http://movies.disney.com/john-carter   49529
# 5       http://www.sonypictures.com/movies/spider-man3/     559
# ...                                                 ...     ...
# 4798                                                NaN    9367
# 4799                                                NaN   72766
# 4800  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4801                        http://shanghaicalling.com/  126186
# 4802                                                NaN   25975
#
#                                                keywords original_language  \
# 1     [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2     [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3     [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4     [{"id": 818, "name": "based on novel"}, {"id":...                en
# 5     [{"id": 851, "name": "dual identity"}, {"id": ...                en
# ...                                                 ...               ...
# 4798  [{"id": 5616, "name": "united states\u2013mexi...                es
# 4799                                                 []                en
# 4800  [{"id": 248, "name": "date"}, {"id": 699, "nam...                en
# 4801                                                 []                en
# 4802  [{"id": 1523, "name": "obsession"}, {"id": 224...                en
#
#                                 original_title  \
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# 5                                 Spider-Man 3
# ...                                        ...
# 4798                               El Mariachi
# 4799                                 Newlyweds
# 4800                 Signed, Sealed, Delivered
# 4801                          Shanghai Calling
# 4802                         My Date with Drew
#
#                                                overview  popularity  \
# 1     Captain Barbossa, long believed to be dead, ha...  139.082615
# 2     A cryptic message from Bond’s past sends him o...  107.376788
# 3     Following the death of District Attorney Harve...  112.312950
# 4     John Carter is a war-weary, former military ca...   43.926995
# 5     The seemingly invincible Spider-Man goes up ag...  115.699814
# ...                                                 ...         ...
# 4798  El Mariachi just wants to play his guitar and ...   14.269792
# 4799  A newlywed couple's honeymoon is upended by th...    0.642552
# 4800  "Signed, Sealed, Delivered" introduces a dedic...    1.444476
# 4801  When ambitious New York attorney Sam is sent t...    0.857008
# 4802  Ever since the second grade when he first saw ...    1.929883
#
#                                    production_companies  \
# 1     [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2     [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3     [{"name": "Legendary Pictures", "id": 923}, {"...
# 4           [{"name": "Walt Disney Pictures", "id": 2}]
# 5     [{"name": "Columbia Pictures", "id": 5}, {"nam...
# ...                                                 ...
# 4798           [{"name": "Columbia Pictures", "id": 5}]
# 4799                                                 []
# 4800  [{"name": "Front Street Pictures", "id": 3958}...
# 4801                                                 []
# 4802  [{"name": "rusty bear entertainment", "id": 87...
#
#                                    production_countries release_date  \
# 1     [{"iso_3166_1": "US", "name": "United States o...   2007-05-19
# 2     [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26
# 3     [{"iso_3166_1": "US", "name": "United States o...   2012-07-16
# 4     [{"iso_3166_1": "US", "name": "United States o...   2012-03-07
# 5     [{"iso_3166_1": "US", "name": "United States o...   2007-05-01
# ...                                                 ...          ...
# 4798  [{"iso_3166_1": "MX", "name": "Mexico"}, {"iso...   1992-09-04
# 4799                                                 []   2011-12-26
# 4800  [{"iso_3166_1": "US", "name": "United States o...   2013-10-13
# 4801  [{"iso_3166_1": "US", "name": "United States o...   2012-05-03
# 4802  [{"iso_3166_1": "US", "name": "United States o...   2005-08-05
#
#          revenue  runtime                                   spoken_languages  \
# 1      961000000    169.0           [{"iso_639_1": "en", "name": "English"}]
# 2      880674609    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...
# 3     1084939099    165.0           [{"iso_639_1": "en", "name": "English"}]
# 4      284139100    132.0           [{"iso_639_1": "en", "name": "English"}]
# 5      890871626    139.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# ...          ...      ...                                                ...
# 4798     2040920     81.0      [{"iso_639_1": "es", "name": "Espa\u00f1ol"}]
# 4799           0     85.0                                                 []
# 4800           0    120.0           [{"iso_639_1": "en", "name": "English"}]
# 4801           0     98.0           [{"iso_639_1": "en", "name": "English"}]
# 4802           0     90.0           [{"iso_639_1": "en", "name": "English"}]
#
#         status                                            tagline  \
# 1     Released     At the end of the world, the adventure begins.
# 2     Released                              A Plan No One Escapes
# 3     Released                                    The Legend Ends
# 4     Released               Lost in our world, found in another.
# 5     Released                                 The battle within.
# ...        ...                                                ...
# 4798  Released  He didn't come looking for trouble, but troubl...
# 4799  Released  A newlywed couple's honeymoon is upended by th...
# 4800  Released                                                NaN
# 4801  Released                           A New Yorker in Shanghai
# 4802  Released                                                NaN
#
#                                          title  vote_average  vote_count
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# 4                                  John Carter           6.1        2124
# 5                                 Spider-Man 3           5.9        3576
# ...                                        ...           ...         ...
# 4798                               El Mariachi           6.6         238
# 4799                                 Newlyweds           5.9           5
# 4800                 Signed, Sealed, Delivered           7.0           6
# 4801                          Shanghai Calling           5.7           7
# 4802                         My Date with Drew           6.3          16
#
# [4802 rows x 20 columns]

# %%
df = df.drop(0)

# %%
df
# Out:
#          budget                                             genres  \
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5     258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 1          http://disney.go.com/disneypictures/pirates/     285
# 2           http://www.sonypictures.com/movies/spectre/  206647
# 3                    http://www.thedarkknightrises.com/   49026
# 4                  http://movies.disney.com/john-carter   49529
# 5       http://www.sonypictures.com/movies/spider-man3/     559
# ...                                                 ...     ...
# 4798                                                NaN    9367
# 4799                                                NaN   72766
# 4800  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4801                        http://shanghaicalling.com/  126186
# 4802                                                NaN   25975
#
#                                                keywords original_language  \
# 1     [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2     [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3     [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4     [{"id": 818, "name": "based on novel"}, {"id":...                en
# 5     [{"id": 851, "name": "dual identity"}, {"id": ...                en
# ...                                                 ...               ...
# 4798  [{"id": 5616, "name": "united states\u2013mexi...                es
# 4799                                                 []                en
# 4800  [{"id": 248, "name": "date"}, {"id": 699, "nam...                en
# 4801                                                 []                en
# 4802  [{"id": 1523, "name": "obsession"}, {"id": 224...                en
#
#                                 original_title  \
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# 5                                 Spider-Man 3
# ...                                        ...
# 4798                               El Mariachi
# 4799                                 Newlyweds
# 4800                 Signed, Sealed, Delivered
# 4801                          Shanghai Calling
# 4802                         My Date with Drew
#
#                                                overview  popularity  \
# 1     Captain Barbossa, long believed to be dead, ha...  139.082615
# 2     A cryptic message from Bond’s past sends him o...  107.376788
# 3     Following the death of District Attorney Harve...  112.312950
# 4     John Carter is a war-weary, former military ca...   43.926995
# 5     The seemingly invincible Spider-Man goes up ag...  115.699814
# ...                                                 ...         ...
# 4798  El Mariachi just wants to play his guitar and ...   14.269792
# 4799  A newlywed couple's honeymoon is upended by th...    0.642552
# 4800  "Signed, Sealed, Delivered" introduces a dedic...    1.444476
# 4801  When ambitious New York attorney Sam is sent t...    0.857008
# 4802  Ever since the second grade when he first saw ...    1.929883
#
#                                    production_companies  \
# 1     [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2     [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3     [{"name": "Legendary Pictures", "id": 923}, {"...
# 4           [{"name": "Walt Disney Pictures", "id": 2}]
# 5     [{"name": "Columbia Pictures", "id": 5}, {"nam...
# ...                                                 ...
# 4798           [{"name": "Columbia Pictures", "id": 5}]
# 4799                                                 []
# 4800  [{"name": "Front Street Pictures", "id": 3958}...
# 4801                                                 []
# 4802  [{"name": "rusty bear entertainment", "id": 87...
#
#                                    production_countries release_date  \
# 1     [{"iso_3166_1": "US", "name": "United States o...   2007-05-19
# 2     [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26
# 3     [{"iso_3166_1": "US", "name": "United States o...   2012-07-16
# 4     [{"iso_3166_1": "US", "name": "United States o...   2012-03-07
# 5     [{"iso_3166_1": "US", "name": "United States o...   2007-05-01
# ...                                                 ...          ...
# 4798  [{"iso_3166_1": "MX", "name": "Mexico"}, {"iso...   1992-09-04
# 4799                                                 []   2011-12-26
# 4800  [{"iso_3166_1": "US", "name": "United States o...   2013-10-13
# 4801  [{"iso_3166_1": "US", "name": "United States o...   2012-05-03
# 4802  [{"iso_3166_1": "US", "name": "United States o...   2005-08-05
#
#          revenue  runtime                                   spoken_languages  \
# 1      961000000    169.0           [{"iso_639_1": "en", "name": "English"}]
# 2      880674609    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...
# 3     1084939099    165.0           [{"iso_639_1": "en", "name": "English"}]
# 4      284139100    132.0           [{"iso_639_1": "en", "name": "English"}]
# 5      890871626    139.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# ...          ...      ...                                                ...
# 4798     2040920     81.0      [{"iso_639_1": "es", "name": "Espa\u00f1ol"}]
# 4799           0     85.0                                                 []
# 4800           0    120.0           [{"iso_639_1": "en", "name": "English"}]
# 4801           0     98.0           [{"iso_639_1": "en", "name": "English"}]
# 4802           0     90.0           [{"iso_639_1": "en", "name": "English"}]
#
#         status                                            tagline  \
# 1     Released     At the end of the world, the adventure begins.
# 2     Released                              A Plan No One Escapes
# 3     Released                                    The Legend Ends
# 4     Released               Lost in our world, found in another.
# 5     Released                                 The battle within.
# ...        ...                                                ...
# 4798  Released  He didn't come looking for trouble, but troubl...
# 4799  Released  A newlywed couple's honeymoon is upended by th...
# 4800  Released                                                NaN
# 4801  Released                           A New Yorker in Shanghai
# 4802  Released                                                NaN
#
#                                          title  vote_average  vote_count
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# 4                                  John Carter           6.1        2124
# 5                                 Spider-Man 3           5.9        3576
# ...                                        ...           ...         ...
# 4798                               El Mariachi           6.6         238
# 4799                                 Newlyweds           5.9           5
# 4800                 Signed, Sealed, Delivered           7.0           6
# 4801                          Shanghai Calling           5.7           7
# 4802                         My Date with Drew           6.3          16
#
# [4802 rows x 20 columns]

# %%
len(df)
# Out:
# 4802

# %%
df
# Out:
#          budget                                             genres  \
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5     258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 1          http://disney.go.com/disneypictures/pirates/     285
# 2           http://www.sonypictures.com/movies/spectre/  206647
# 3                    http://www.thedarkknightrises.com/   49026
# 4                  http://movies.disney.com/john-carter   49529
# 5       http://www.sonypictures.com/movies/spider-man3/     559
# ...                                                 ...     ...
# 4798                                                NaN    9367
# 4799                                                NaN   72766
# 4800  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4801                        http://shanghaicalling.com/  126186
# 4802                                                NaN   25975
#
#                                                keywords original_language  \
# 1     [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2     [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3     [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4     [{"id": 818, "name": "based on novel"}, {"id":...                en
# 5     [{"id": 851, "name": "dual identity"}, {"id": ...                en
# ...                                                 ...               ...
# 4798  [{"id": 5616, "name": "united states\u2013mexi...                es
# 4799                                                 []                en
# 4800  [{"id": 248, "name": "date"}, {"id": 699, "nam...                en
# 4801                                                 []                en
# 4802  [{"id": 1523, "name": "obsession"}, {"id": 224...                en
#
#                                 original_title  \
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# 5                                 Spider-Man 3
# ...                                        ...
# 4798                               El Mariachi
# 4799                                 Newlyweds
# 4800                 Signed, Sealed, Delivered
# 4801                          Shanghai Calling
# 4802                         My Date with Drew
#
#                                                overview  popularity  \
# 1     Captain Barbossa, long believed to be dead, ha...  139.082615
# 2     A cryptic message from Bond’s past sends him o...  107.376788
# 3     Following the death of District Attorney Harve...  112.312950
# 4     John Carter is a war-weary, former military ca...   43.926995
# 5     The seemingly invincible Spider-Man goes up ag...  115.699814
# ...                                                 ...         ...
# 4798  El Mariachi just wants to play his guitar and ...   14.269792
# 4799  A newlywed couple's honeymoon is upended by th...    0.642552
# 4800  "Signed, Sealed, Delivered" introduces a dedic...    1.444476
# 4801  When ambitious New York attorney Sam is sent t...    0.857008
# 4802  Ever since the second grade when he first saw ...    1.929883
#
#                                    production_companies  \
# 1     [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2     [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3     [{"name": "Legendary Pictures", "id": 923}, {"...
# 4           [{"name": "Walt Disney Pictures", "id": 2}]
# 5     [{"name": "Columbia Pictures", "id": 5}, {"nam...
# ...                                                 ...
# 4798           [{"name": "Columbia Pictures", "id": 5}]
# 4799                                                 []
# 4800  [{"name": "Front Street Pictures", "id": 3958}...
# 4801                                                 []
# 4802  [{"name": "rusty bear entertainment", "id": 87...
#
#                                    production_countries release_date  \
# 1     [{"iso_3166_1": "US", "name": "United States o...   2007-05-19
# 2     [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26
# 3     [{"iso_3166_1": "US", "name": "United States o...   2012-07-16
# 4     [{"iso_3166_1": "US", "name": "United States o...   2012-03-07
# 5     [{"iso_3166_1": "US", "name": "United States o...   2007-05-01
# ...                                                 ...          ...
# 4798  [{"iso_3166_1": "MX", "name": "Mexico"}, {"iso...   1992-09-04
# 4799                                                 []   2011-12-26
# 4800  [{"iso_3166_1": "US", "name": "United States o...   2013-10-13
# 4801  [{"iso_3166_1": "US", "name": "United States o...   2012-05-03
# 4802  [{"iso_3166_1": "US", "name": "United States o...   2005-08-05
#
#          revenue  runtime                                   spoken_languages  \
# 1      961000000    169.0           [{"iso_639_1": "en", "name": "English"}]
# 2      880674609    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...
# 3     1084939099    165.0           [{"iso_639_1": "en", "name": "English"}]
# 4      284139100    132.0           [{"iso_639_1": "en", "name": "English"}]
# 5      890871626    139.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# ...          ...      ...                                                ...
# 4798     2040920     81.0      [{"iso_639_1": "es", "name": "Espa\u00f1ol"}]
# 4799           0     85.0                                                 []
# 4800           0    120.0           [{"iso_639_1": "en", "name": "English"}]
# 4801           0     98.0           [{"iso_639_1": "en", "name": "English"}]
# 4802           0     90.0           [{"iso_639_1": "en", "name": "English"}]
#
#         status                                            tagline  \
# 1     Released     At the end of the world, the adventure begins.
# 2     Released                              A Plan No One Escapes
# 3     Released                                    The Legend Ends
# 4     Released               Lost in our world, found in another.
# 5     Released                                 The battle within.
# ...        ...                                                ...
# 4798  Released  He didn't come looking for trouble, but troubl...
# 4799  Released  A newlywed couple's honeymoon is upended by th...
# 4800  Released                                                NaN
# 4801  Released                           A New Yorker in Shanghai
# 4802  Released                                                NaN
#
#                                          title  vote_average  vote_count
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# 4                                  John Carter           6.1        2124
# 5                                 Spider-Man 3           5.9        3576
# ...                                        ...           ...         ...
# 4798                               El Mariachi           6.6         238
# 4799                                 Newlyweds           5.9           5
# 4800                 Signed, Sealed, Delivered           7.0           6
# 4801                          Shanghai Calling           5.7           7
# 4802                         My Date with Drew           6.3          16
#
# [4802 rows x 20 columns]

# %%
df = pd.read_csv('dataset/tmdb_5000_movies.csv')
df[(df['original_language'] == 'ja') & (df['vote_average'] > 8)]
# Out:
#         budget                                             genres  \
# 1987  24000000  [{"id": 14, "name": "Fantasy"}, {"id": 16, "na...
# 2247  26500000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2294  15000000  [{"id": 14, "name": "Fantasy"}, {"id": 12, "na...
# 4535   2000000  [{"id": 28, "name": "Action"}, {"id": 18, "nam...
#
#                                     homepage    id  \
# 1987                                     NaN  4935
# 2247                                     NaN   128
# 2294  http://movies.disney.com/spirited-away   129
# 4535                                     NaN   346
#
#                                                keywords original_language  \
# 1987  [{"id": 334, "name": "flying"}, {"id": 616, "n...                ja
# 2247  [{"id": 1721, "name": "fight"}, {"id": 1994, "...                ja
# 2294  [{"id": 616, "name": "witch"}, {"id": 970, "na...                ja
# 4535  [{"id": 233, "name": "japan"}, {"id": 1462, "n...                ja
#
#      original_title                                           overview  \
# 1987        ハウルの動く城  When Sophie, a shy young woman, is cursed with...
# 2247          もののけ姫  Ashitaka, a prince of the disappearing Ainu tr...
# 2294       千と千尋の神隠し  A ten year old girl who wanders away from her ...
# 4535           七人の侍  A samurai answers a village's request for prot...
#
#       popularity                               production_companies  \
# 1987   49.549984  [{"name": "Studio Ghibli", "id": 10342}, {"nam...
# 2247   60.732738  [{"name": "Miramax Films", "id": 14}, {"name":...
# 2294  118.968562           [{"name": "Studio Ghibli", "id": 10342}]
# 4535   39.756748              [{"name": "Toho Company", "id": 882}]
#
#                          production_countries release_date    revenue  \
# 1987  [{"iso_3166_1": "JP", "name": "Japan"}]   2004-11-19  234710455
# 2247  [{"iso_3166_1": "JP", "name": "Japan"}]   1997-07-12  159375308
# 2294  [{"iso_3166_1": "JP", "name": "Japan"}]   2001-07-20  274925095
# 4535  [{"iso_3166_1": "JP", "name": "Japan"}]   1954-04-26     271841
#
#       runtime                                   spoken_languages    status  \
# 1987    119.0  [{"iso_639_1": "ja", "name": "\u65e5\u672c\u8a...  Released
# 2247    134.0  [{"iso_639_1": "ja", "name": "\u65e5\u672c\u8a...  Released
# 2294    125.0  [{"iso_639_1": "ja", "name": "\u65e5\u672c\u8a...  Released
# 4535    207.0  [{"iso_639_1": "ja", "name": "\u65e5\u672c\u8a...  Released
#
#                                                 tagline                 title  \
# 1987                                The two lived there  Howl's Moving Castle
# 2247  The Fate Of The World Rests On The Courage Of ...     Princess Mononoke
# 2294     The tunnel led Chihiro to a mysterious town...         Spirited Away
# 4535  The Mighty Warriors Who Became the Seven Natio...         Seven Samurai
#
#       vote_average  vote_count
# 1987           8.2        1991
# 2247           8.2        1983
# 2294           8.3        3840
# 4535           8.2         878

# %%
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# 1          http://disney.go.com/disneypictures/pirates/     285
# 2           http://www.sonypictures.com/movies/spectre/  206647
# 3                    http://www.thedarkknightrises.com/   49026
# 4                  http://movies.disney.com/john-carter   49529
# ...                                                 ...     ...
# 4798                                                NaN    9367
# 4799                                                NaN   72766
# 4800  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4801                        http://shanghaicalling.com/  126186
# 4802                                                NaN   25975
#
#                                                keywords original_language  \
# 0     [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1     [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2     [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3     [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4     [{"id": 818, "name": "based on novel"}, {"id":...                en
# ...                                                 ...               ...
# 4798  [{"id": 5616, "name": "united states\u2013mexi...                es
# 4799                                                 []                en
# 4800  [{"id": 248, "name": "date"}, {"id": 699, "nam...                en
# 4801                                                 []                en
# 4802  [{"id": 1523, "name": "obsession"}, {"id": 224...                en
#
#                                 original_title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4798                               El Mariachi
# 4799                                 Newlyweds
# 4800                 Signed, Sealed, Delivered
# 4801                          Shanghai Calling
# 4802                         My Date with Drew
#
#                                                overview  popularity  \
# 0     In the 22nd century, a paraplegic Marine is di...  150.437577
# 1     Captain Barbossa, long believed to be dead, ha...  139.082615
# 2     A cryptic message from Bond’s past sends him o...  107.376788
# 3     Following the death of District Attorney Harve...  112.312950
# 4     John Carter is a war-weary, former military ca...   43.926995
# ...                                                 ...         ...
# 4798  El Mariachi just wants to play his guitar and ...   14.269792
# 4799  A newlywed couple's honeymoon is upended by th...    0.642552
# 4800  "Signed, Sealed, Delivered" introduces a dedic...    1.444476
# 4801  When ambitious New York attorney Sam is sent t...    0.857008
# 4802  Ever since the second grade when he first saw ...    1.929883
#
#                                    production_companies  \
# 0     [{"name": "Ingenious Film Partners", "id": 289...
# 1     [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2     [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3     [{"name": "Legendary Pictures", "id": 923}, {"...
# 4           [{"name": "Walt Disney Pictures", "id": 2}]
# ...                                                 ...
# 4798           [{"name": "Columbia Pictures", "id": 5}]
# 4799                                                 []
# 4800  [{"name": "Front Street Pictures", "id": 3958}...
# 4801                                                 []
# 4802  [{"name": "rusty bear entertainment", "id": 87...
#
#                                    production_countries release_date  \
# 0     [{"iso_3166_1": "US", "name": "United States o...   2009-12-10
# 1     [{"iso_3166_1": "US", "name": "United States o...   2007-05-19
# 2     [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26
# 3     [{"iso_3166_1": "US", "name": "United States o...   2012-07-16
# 4     [{"iso_3166_1": "US", "name": "United States o...   2012-03-07
# ...                                                 ...          ...
# 4798  [{"iso_3166_1": "MX", "name": "Mexico"}, {"iso...   1992-09-04
# 4799                                                 []   2011-12-26
# 4800  [{"iso_3166_1": "US", "name": "United States o...   2013-10-13
# 4801  [{"iso_3166_1": "US", "name": "United States o...   2012-05-03
# 4802  [{"iso_3166_1": "US", "name": "United States o...   2005-08-05
#
#          revenue  runtime                                   spoken_languages  \
# 0     2787965087    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 1      961000000    169.0           [{"iso_639_1": "en", "name": "English"}]
# 2      880674609    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...
# 3     1084939099    165.0           [{"iso_639_1": "en", "name": "English"}]
# 4      284139100    132.0           [{"iso_639_1": "en", "name": "English"}]
# ...          ...      ...                                                ...
# 4798     2040920     81.0      [{"iso_639_1": "es", "name": "Espa\u00f1ol"}]
# 4799           0     85.0                                                 []
# 4800           0    120.0           [{"iso_639_1": "en", "name": "English"}]
# 4801           0     98.0           [{"iso_639_1": "en", "name": "English"}]
# 4802           0     90.0           [{"iso_639_1": "en", "name": "English"}]
#
#         status                                            tagline  \
# 0     Released                        Enter the World of Pandora.
# 1     Released     At the end of the world, the adventure begins.
# 2     Released                              A Plan No One Escapes
# 3     Released                                    The Legend Ends
# 4     Released               Lost in our world, found in another.
# ...        ...                                                ...
# 4798  Released  He didn't come looking for trouble, but troubl...
# 4799  Released  A newlywed couple's honeymoon is upended by th...
# 4800  Released                                                NaN
# 4801  Released                           A New Yorker in Shanghai
# 4802  Released                                                NaN
#
#                                          title  vote_average  vote_count
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# 4                                  John Carter           6.1        2124
# ...                                        ...           ...         ...
# 4798                               El Mariachi           6.6         238
# 4799                                 Newlyweds           5.9           5
# 4800                 Signed, Sealed, Delivered           7.0           6
# 4801                          Shanghai Calling           5.7           7
# 4802                         My Date with Drew           6.3          16
#
# [4803 rows x 20 columns]

# %% [markdown]
# Index操作

# %% [markdown]
# ## .reset_index()で再度indexを割り振る

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# 1          http://disney.go.com/disneypictures/pirates/     285
# 2           http://www.sonypictures.com/movies/spectre/  206647
# 3                    http://www.thedarkknightrises.com/   49026
# 4                  http://movies.disney.com/john-carter   49529
# ...                                                 ...     ...
# 4798                                                NaN    9367
# 4799                                                NaN   72766
# 4800  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4801                        http://shanghaicalling.com/  126186
# 4802                                                NaN   25975
#
#                                                keywords original_language  \
# 0     [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1     [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2     [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3     [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4     [{"id": 818, "name": "based on novel"}, {"id":...                en
# ...                                                 ...               ...
# 4798  [{"id": 5616, "name": "united states\u2013mexi...                es
# 4799                                                 []                en
# 4800  [{"id": 248, "name": "date"}, {"id": 699, "nam...                en
# 4801                                                 []                en
# 4802  [{"id": 1523, "name": "obsession"}, {"id": 224...                en
#
#                                 original_title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4798                               El Mariachi
# 4799                                 Newlyweds
# 4800                 Signed, Sealed, Delivered
# 4801                          Shanghai Calling
# 4802                         My Date with Drew
#
#                                                overview  popularity  \
# 0     In the 22nd century, a paraplegic Marine is di...  150.437577
# 1     Captain Barbossa, long believed to be dead, ha...  139.082615
# 2     A cryptic message from Bond’s past sends him o...  107.376788
# 3     Following the death of District Attorney Harve...  112.312950
# 4     John Carter is a war-weary, former military ca...   43.926995
# ...                                                 ...         ...
# 4798  El Mariachi just wants to play his guitar and ...   14.269792
# 4799  A newlywed couple's honeymoon is upended by th...    0.642552
# 4800  "Signed, Sealed, Delivered" introduces a dedic...    1.444476
# 4801  When ambitious New York attorney Sam is sent t...    0.857008
# 4802  Ever since the second grade when he first saw ...    1.929883
#
#                                    production_companies  \
# 0     [{"name": "Ingenious Film Partners", "id": 289...
# 1     [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2     [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3     [{"name": "Legendary Pictures", "id": 923}, {"...
# 4           [{"name": "Walt Disney Pictures", "id": 2}]
# ...                                                 ...
# 4798           [{"name": "Columbia Pictures", "id": 5}]
# 4799                                                 []
# 4800  [{"name": "Front Street Pictures", "id": 3958}...
# 4801                                                 []
# 4802  [{"name": "rusty bear entertainment", "id": 87...
#
#                                    production_countries release_date  \
# 0     [{"iso_3166_1": "US", "name": "United States o...   2009-12-10
# 1     [{"iso_3166_1": "US", "name": "United States o...   2007-05-19
# 2     [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26
# 3     [{"iso_3166_1": "US", "name": "United States o...   2012-07-16
# 4     [{"iso_3166_1": "US", "name": "United States o...   2012-03-07
# ...                                                 ...          ...
# 4798  [{"iso_3166_1": "MX", "name": "Mexico"}, {"iso...   1992-09-04
# 4799                                                 []   2011-12-26
# 4800  [{"iso_3166_1": "US", "name": "United States o...   2013-10-13
# 4801  [{"iso_3166_1": "US", "name": "United States o...   2012-05-03
# 4802  [{"iso_3166_1": "US", "name": "United States o...   2005-08-05
#
#          revenue  runtime                                   spoken_languages  \
# 0     2787965087    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 1      961000000    169.0           [{"iso_639_1": "en", "name": "English"}]
# 2      880674609    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...
# 3     1084939099    165.0           [{"iso_639_1": "en", "name": "English"}]
# 4      284139100    132.0           [{"iso_639_1": "en", "name": "English"}]
# ...          ...      ...                                                ...
# 4798     2040920     81.0      [{"iso_639_1": "es", "name": "Espa\u00f1ol"}]
# 4799           0     85.0                                                 []
# 4800           0    120.0           [{"iso_639_1": "en", "name": "English"}]
# 4801           0     98.0           [{"iso_639_1": "en", "name": "English"}]
# 4802           0     90.0           [{"iso_639_1": "en", "name": "English"}]
#
#         status                                            tagline  \
# 0     Released                        Enter the World of Pandora.
# 1     Released     At the end of the world, the adventure begins.
# 2     Released                              A Plan No One Escapes
# 3     Released                                    The Legend Ends
# 4     Released               Lost in our world, found in another.
# ...        ...                                                ...
# 4798  Released  He didn't come looking for trouble, but troubl...
# 4799  Released  A newlywed couple's honeymoon is upended by th...
# 4800  Released                                                NaN
# 4801  Released                           A New Yorker in Shanghai
# 4802  Released                                                NaN
#
#                                          title  vote_average  vote_count
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# 4                                  John Carter           6.1        2124
# ...                                        ...           ...         ...
# 4798                               El Mariachi           6.6         238
# 4799                                 Newlyweds           5.9           5
# 4800                 Signed, Sealed, Delivered           7.0           6
# 4801                          Shanghai Calling           5.7           7
# 4802                         My Date with Drew           6.3          16
#
# [4803 rows x 20 columns]

# %% [markdown]
# ## set_index()

# %%
df = pd.read_csv('dataset/tmdb_5000_movies.csv')
df = df.set_index('id')
df.head(3)
# Out:
#            budget                                             genres  \
# id
# 19995   237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 285     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 206647  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             homepage  \
# id
# 19995                    http://www.avatarmovie.com/
# 285     http://disney.go.com/disneypictures/pirates/
# 206647   http://www.sonypictures.com/movies/spectre/
#
#                                                  keywords original_language  \
# id
# 19995   [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 285     [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 206647  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
#
#                                   original_title  \
# id
# 19995                                     Avatar
# 285     Pirates of the Caribbean: At World's End
# 206647                                   Spectre
#
#                                                  overview  popularity  \
# id
# 19995   In the 22nd century, a paraplegic Marine is di...  150.437577
# 285     Captain Barbossa, long believed to be dead, ha...  139.082615
# 206647  A cryptic message from Bond’s past sends him o...  107.376788
#
#                                      production_companies  \
# id
# 19995   [{"name": "Ingenious Film Partners", "id": 289...
# 285     [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 206647  [{"name": "Columbia Pictures", "id": 5}, {"nam...
#
#                                      production_countries release_date  \
# id
# 19995   [{"iso_3166_1": "US", "name": "United States o...   2009-12-10
# 285     [{"iso_3166_1": "US", "name": "United States o...   2007-05-19
# 206647  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26
#
#            revenue  runtime  \
# id
# 19995   2787965087    162.0
# 285      961000000    169.0
# 206647   880674609    148.0
#
#                                          spoken_languages    status  \
# id
# 19995   [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 285              [{"iso_639_1": "en", "name": "English"}]  Released
# 206647  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
#
#                                                tagline  \
# id
# 19995                      Enter the World of Pandora.
# 285     At the end of the world, the adventure begins.
# 206647                           A Plan No One Escapes
#
#                                            title  vote_average  vote_count
# id
# 19995                                     Avatar           7.2       11800
# 285     Pirates of the Caribbean: At World's End           6.9        4500
# 206647                                   Spectre           6.3        4466

# %% [markdown]
# ## .dropna

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#            budget                                             genres  \
# id
# 19995   237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 285     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 206647  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 49026   250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 49529   260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...           ...                                                ...
# 2292        27000                     [{"id": 35, "name": "Comedy"}]
# 255266      22000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 157185         13                     [{"id": 27, "name": "Horror"}]
# 14337        7000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 126186          0                                                 []
#
#                                             homepage  \
# id
# 19995                    http://www.avatarmovie.com/
# 285     http://disney.go.com/disneypictures/pirates/
# 206647   http://www.sonypictures.com/movies/spectre/
# 49026             http://www.thedarkknightrises.com/
# 49529           http://movies.disney.com/john-carter
# ...                                              ...
# 2292            http://www.miramax.com/movie/clerks/
# 255266        https://www.facebook.com/DrySpellMovie
# 157185                 http://tincanmanthemovie.com/
# 14337                     http://www.primermovie.com
# 126186                   http://shanghaicalling.com/
#
#                                                  keywords original_language  \
# id
# 19995   [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 285     [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 206647  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 49026   [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 49529   [{"id": 818, "name": "based on novel"}, {"id":...                en
# ...                                                   ...               ...
# 2292    [{"id": 1361, "name": "salesclerk"}, {"id": 30...                en
# 255266  [{"id": 13043, "name": "dating"}, {"id": 15160...                en
# 157185           [{"id": 14903, "name": "home invasion"}]                en
# 14337   [{"id": 1448, "name": "distrust"}, {"id": 2101...                en
# 126186                                                 []                en
#
#                                   original_title  \
# id
# 19995                                     Avatar
# 285     Pirates of the Caribbean: At World's End
# 206647                                   Spectre
# 49026                      The Dark Knight Rises
# 49529                                John Carter
# ...                                          ...
# 2292                                      Clerks
# 255266                                 Dry Spell
# 157185                               Tin Can Man
# 14337                                     Primer
# 126186                          Shanghai Calling
#
#                                                  overview  popularity  \
# id
# 19995   In the 22nd century, a paraplegic Marine is di...  150.437577
# 285     Captain Barbossa, long believed to be dead, ha...  139.082615
# 206647  A cryptic message from Bond’s past sends him o...  107.376788
# 49026   Following the death of District Attorney Harve...  112.312950
# 49529   John Carter is a war-weary, former military ca...   43.926995
# ...                                                   ...         ...
# 2292    Convenience and video store clerks Dante and R...   19.748658
# 255266  Sasha tries to get her soon-to-be ex husband K...    0.048948
# 157185  Recently dumped by his girlfirend for another ...    0.332679
# 14337   Friends/fledgling entrepreneurs invent a devic...   23.307949
# 126186  When ambitious New York attorney Sam is sent t...    0.857008
#
#                                      production_companies  \
# id
# 19995   [{"name": "Ingenious Film Partners", "id": 289...
# 285     [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 206647  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 49026   [{"name": "Legendary Pictures", "id": 923}, {"...
# 49529         [{"name": "Walt Disney Pictures", "id": 2}]
# ...                                                   ...
# 2292    [{"name": "Miramax Films", "id": 14}, {"name":...
# 255266                                                 []
# 157185  [{"name": "Park Films", "id": 21871}, {"name":...
# 14337                  [{"name": "Thinkfilm", "id": 446}]
# 126186                                                 []
#
#                                      production_countries release_date  \
# id
# 19995   [{"iso_3166_1": "US", "name": "United States o...   2009-12-10
# 285     [{"iso_3166_1": "US", "name": "United States o...   2007-05-19
# 206647  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26
# 49026   [{"iso_3166_1": "US", "name": "United States o...   2012-07-16
# 49529   [{"iso_3166_1": "US", "name": "United States o...   2012-03-07
# ...                                                   ...          ...
# 2292    [{"iso_3166_1": "US", "name": "United States o...   1994-09-13
# 255266  [{"iso_3166_1": "US", "name": "United States o...   2013-02-14
# 157185          [{"iso_3166_1": "IE", "name": "Ireland"}]   2007-01-01
# 14337   [{"iso_3166_1": "US", "name": "United States o...   2004-10-08
# 126186  [{"iso_3166_1": "US", "name": "United States o...   2012-05-03
#
#            revenue  runtime  \
# id
# 19995   2787965087    162.0
# 285      961000000    169.0
# 206647   880674609    148.0
# 49026   1084939099    165.0
# 49529    284139100    132.0
# ...            ...      ...
# 2292       3151130     92.0
# 255266           0     90.0
# 157185           0     84.0
# 14337       424760     77.0
# 126186           0     98.0
#
#                                          spoken_languages    status  \
# id
# 19995   [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 285              [{"iso_639_1": "en", "name": "English"}]  Released
# 206647  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 49026            [{"iso_639_1": "en", "name": "English"}]  Released
# 49529            [{"iso_639_1": "en", "name": "English"}]  Released
# ...                                                   ...       ...
# 2292             [{"iso_639_1": "en", "name": "English"}]  Released
# 255266           [{"iso_639_1": "en", "name": "English"}]  Released
# 157185           [{"iso_639_1": "en", "name": "English"}]  Released
# 14337            [{"iso_639_1": "en", "name": "English"}]  Released
# 126186           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                                   tagline  \
# id
# 19995                         Enter the World of Pandora.
# 285        At the end of the world, the adventure begins.
# 206647                              A Plan No One Escapes
# 49026                                     The Legend Ends
# 49529                Lost in our world, found in another.
# ...                                                   ...
# 2292    Just because they serve you doesn't mean they ...
# 255266       Getting divorced does funny things to a girl
# 157185                    Everything You've Heard is True
# 14337                  What happens if it actually works?
# 126186                           A New Yorker in Shanghai
#
#                                            title  vote_average  vote_count
# id
# 19995                                     Avatar           7.2       11800
# 285     Pirates of the Caribbean: At World's End           6.9        4500
# 206647                                   Spectre           6.3        4466
# 49026                      The Dark Knight Rises           7.6        9106
# 49529                                John Carter           6.1        2124
# ...                                          ...           ...         ...
# 2292                                      Clerks           7.4         755
# 255266                                 Dry Spell           6.0           1
# 157185                               Tin Can Man           2.0           1
# 14337                                     Primer           6.9         658
# 126186                          Shanghai Calling           5.7           7
#
# [1493 rows x 19 columns]

# %% [markdown]
# ## .filna()

# %%
df['runtime'].mean()
# Out:
# 108.65773610180844

# %%
df['runtime'] = df['runtime'].fillna(df['runtime'].mean())

# %%
df
# Out:
#            budget                                             genres  \
# id
# 19995   237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 285     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 206647  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 49026   250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 49529   260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...           ...                                                ...
# 2292        27000                     [{"id": 35, "name": "Comedy"}]
# 255266      22000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 157185         13                     [{"id": 27, "name": "Horror"}]
# 14337        7000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 126186          0                                                 []
#
#                                             homepage  \
# id
# 19995                    http://www.avatarmovie.com/
# 285     http://disney.go.com/disneypictures/pirates/
# 206647   http://www.sonypictures.com/movies/spectre/
# 49026             http://www.thedarkknightrises.com/
# 49529           http://movies.disney.com/john-carter
# ...                                              ...
# 2292            http://www.miramax.com/movie/clerks/
# 255266        https://www.facebook.com/DrySpellMovie
# 157185                 http://tincanmanthemovie.com/
# 14337                     http://www.primermovie.com
# 126186                   http://shanghaicalling.com/
#
#                                                  keywords original_language  \
# id
# 19995   [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 285     [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 206647  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 49026   [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 49529   [{"id": 818, "name": "based on novel"}, {"id":...                en
# ...                                                   ...               ...
# 2292    [{"id": 1361, "name": "salesclerk"}, {"id": 30...                en
# 255266  [{"id": 13043, "name": "dating"}, {"id": 15160...                en
# 157185           [{"id": 14903, "name": "home invasion"}]                en
# 14337   [{"id": 1448, "name": "distrust"}, {"id": 2101...                en
# 126186                                                 []                en
#
#                                   original_title  \
# id
# 19995                                     Avatar
# 285     Pirates of the Caribbean: At World's End
# 206647                                   Spectre
# 49026                      The Dark Knight Rises
# 49529                                John Carter
# ...                                          ...
# 2292                                      Clerks
# 255266                                 Dry Spell
# 157185                               Tin Can Man
# 14337                                     Primer
# 126186                          Shanghai Calling
#
#                                                  overview  popularity  \
# id
# 19995   In the 22nd century, a paraplegic Marine is di...  150.437577
# 285     Captain Barbossa, long believed to be dead, ha...  139.082615
# 206647  A cryptic message from Bond’s past sends him o...  107.376788
# 49026   Following the death of District Attorney Harve...  112.312950
# 49529   John Carter is a war-weary, former military ca...   43.926995
# ...                                                   ...         ...
# 2292    Convenience and video store clerks Dante and R...   19.748658
# 255266  Sasha tries to get her soon-to-be ex husband K...    0.048948
# 157185  Recently dumped by his girlfirend for another ...    0.332679
# 14337   Friends/fledgling entrepreneurs invent a devic...   23.307949
# 126186  When ambitious New York attorney Sam is sent t...    0.857008
#
#                                      production_companies  \
# id
# 19995   [{"name": "Ingenious Film Partners", "id": 289...
# 285     [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 206647  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 49026   [{"name": "Legendary Pictures", "id": 923}, {"...
# 49529         [{"name": "Walt Disney Pictures", "id": 2}]
# ...                                                   ...
# 2292    [{"name": "Miramax Films", "id": 14}, {"name":...
# 255266                                                 []
# 157185  [{"name": "Park Films", "id": 21871}, {"name":...
# 14337                  [{"name": "Thinkfilm", "id": 446}]
# 126186                                                 []
#
#                                      production_countries release_date  \
# id
# 19995   [{"iso_3166_1": "US", "name": "United States o...   2009-12-10
# 285     [{"iso_3166_1": "US", "name": "United States o...   2007-05-19
# 206647  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26
# 49026   [{"iso_3166_1": "US", "name": "United States o...   2012-07-16
# 49529   [{"iso_3166_1": "US", "name": "United States o...   2012-03-07
# ...                                                   ...          ...
# 2292    [{"iso_3166_1": "US", "name": "United States o...   1994-09-13
# 255266  [{"iso_3166_1": "US", "name": "United States o...   2013-02-14
# 157185          [{"iso_3166_1": "IE", "name": "Ireland"}]   2007-01-01
# 14337   [{"iso_3166_1": "US", "name": "United States o...   2004-10-08
# 126186  [{"iso_3166_1": "US", "name": "United States o...   2012-05-03
#
#            revenue  runtime  \
# id
# 19995   2787965087    162.0
# 285      961000000    169.0
# 206647   880674609    148.0
# 49026   1084939099    165.0
# 49529    284139100    132.0
# ...            ...      ...
# 2292       3151130     92.0
# 255266           0     90.0
# 157185           0     84.0
# 14337       424760     77.0
# 126186           0     98.0
#
#                                          spoken_languages    status  \
# id
# 19995   [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 285              [{"iso_639_1": "en", "name": "English"}]  Released
# 206647  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 49026            [{"iso_639_1": "en", "name": "English"}]  Released
# 49529            [{"iso_639_1": "en", "name": "English"}]  Released
# ...                                                   ...       ...
# 2292             [{"iso_639_1": "en", "name": "English"}]  Released
# 255266           [{"iso_639_1": "en", "name": "English"}]  Released
# 157185           [{"iso_639_1": "en", "name": "English"}]  Released
# 14337            [{"iso_639_1": "en", "name": "English"}]  Released
# 126186           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                                   tagline  \
# id
# 19995                         Enter the World of Pandora.
# 285        At the end of the world, the adventure begins.
# 206647                              A Plan No One Escapes
# 49026                                     The Legend Ends
# 49529                Lost in our world, found in another.
# ...                                                   ...
# 2292    Just because they serve you doesn't mean they ...
# 255266       Getting divorced does funny things to a girl
# 157185                    Everything You've Heard is True
# 14337                  What happens if it actually works?
# 126186                           A New Yorker in Shanghai
#
#                                            title  vote_average  vote_count
# id
# 19995                                     Avatar           7.2       11800
# 285     Pirates of the Caribbean: At World's End           6.9        4500
# 206647                                   Spectre           6.3        4466
# 49026                      The Dark Knight Rises           7.6        9106
# 49529                                John Carter           6.1        2124
# ...                                          ...           ...         ...
# 2292                                      Clerks           7.4         755
# 255266                                 Dry Spell           6.0           1
# 157185                               Tin Can Man           2.0           1
# 14337                                     Primer           6.9         658
# 126186                          Shanghai Calling           5.7           7
#
# [1493 rows x 19 columns]

# %%
df.groupby('original_language').mean().loc['ja']
# Out:
# budget          1.130000e+07
# popularity      3.520743e+01
# revenue         7.182791e+07
# runtime         1.112000e+02
# vote_average    6.840000e+00
# vote_count      9.776000e+02
# Name: ja, dtype: float64

# %%
df[df['original_language'] == 'ja']['budget']
# Out:
# id
# 129       15000000
# 327       12000000
# 149        8000000
# 193722     5500000
# 10991     16000000
# Name: budget, dtype: int64

# %%
df.groupby('original_language').describe()
# Out:
#                    budget                                                      \
#                     count          mean           std         min         25%
# original_language
# af                    1.0  3.000000e+06           NaN   3000000.0   3000000.0
# ar                    1.0  0.000000e+00           NaN         0.0         0.0
# cn                    1.0  2.300000e+07           NaN  23000000.0  23000000.0
# cs                    1.0  0.000000e+00           NaN         0.0         0.0
# de                    5.0  9.227950e+06  6.857680e+06   1500000.0   4800000.0
# el                    1.0  0.000000e+00           NaN         0.0         0.0
# en                 1435.0  4.737835e+07  5.417949e+07         0.0   8500000.0
# es                    9.0  5.377763e+06  6.478171e+06         0.0   1500000.0
# fa                    1.0  1.800000e+05           NaN    180000.0    180000.0
# fr                    9.0  7.822222e+06  7.629839e+06         0.0   4000000.0
# hi                    4.0  3.125000e+05  6.250000e+05         0.0         0.0
# id                    2.0  1.050000e+06  7.071068e+04   1000000.0   1025000.0
# it                    1.0  1.200000e+06           NaN   1200000.0   1200000.0
# ja                    5.0  1.130000e+07  4.494441e+06   5500000.0   8000000.0
# ko                    3.0  1.673333e+07  2.021913e+07         0.0   5500000.0
# nb                    1.0  3.500000e+06           NaN   3500000.0   3500000.0
# nl                    1.0  4.000000e+06           NaN   4000000.0   4000000.0
# no                    1.0  8.000000e+05           NaN    800000.0    800000.0
# pt                    2.0  3.650000e+06  4.949747e+05   3300000.0   3475000.0
# ru                    1.0  3.000000e+07           NaN  30000000.0  30000000.0
# th                    1.0  8.500000e+06           NaN   8500000.0   8500000.0
# zh                    7.0  2.533444e+07  2.837498e+07         0.0   6000055.0
#
#                                                        popularity             \
#                           50%         75%          max      count       mean
# original_language
# af                  3000000.0   3000000.0    3000000.0        1.0   2.504169
# ar                        0.0         0.0          0.0        1.0   4.892203
# cn                 23000000.0  23000000.0   23000000.0        1.0   7.876883
# cs                        0.0         0.0          0.0        1.0   0.186234
# de                  7500000.0  14000000.0   18339750.0        5.0  19.719163
# el                        0.0         0.0          0.0        1.0  28.858238
# en                 29000000.0  65000000.0  380000000.0     1435.0  36.416560
# es                  2600000.0   5600000.0   19000000.0        9.0  22.302296
# fa                   180000.0    180000.0     180000.0        1.0   7.072118
# fr                  6800000.0  10000000.0   25000000.0        9.0  18.988647
# hi                        0.0    312500.0    1250000.0        4.0   0.819444
# id                  1050000.0   1075000.0    1100000.0        2.0  24.586253
# it                  1200000.0   1200000.0    1200000.0        1.0  88.377076
# ja                 12000000.0  15000000.0   16000000.0        5.0  35.207429
# ko                 11000000.0  25100000.0   39200000.0        3.0  36.322934
# nb                  3500000.0   3500000.0    3500000.0        1.0  12.982319
# nl                  4000000.0   4000000.0    4000000.0        1.0   5.013575
# no                   800000.0    800000.0     800000.0        1.0  11.205726
# pt                  3650000.0   3825000.0    4000000.0        2.0  33.980823
# ru                 30000000.0  30000000.0   30000000.0        1.0   2.625594
# th                  8500000.0   8500000.0    8500000.0        1.0   9.029489
# zh                 15000000.0  35000000.0   80341000.0        7.0   8.522394
#
#                    ... vote_average      vote_count                            \
#                    ...          75%  max      count         mean          std
# original_language  ...
# af                 ...        6.900  6.9        1.0    94.000000          NaN
# ar                 ...        7.800  7.8        1.0    55.000000          NaN
# cn                 ...        6.500  6.5        1.0    57.000000          NaN
# cs                 ...        4.300  4.3        1.0     2.000000          NaN
# de                 ...        7.700  7.9        5.0   625.800000   369.591261
# el                 ...        6.900  6.9        1.0   332.000000          NaN
# en                 ...        6.900  8.4     1435.0  1355.110801  1813.134751
# es                 ...        7.100  7.6        9.0   616.111111   952.339677
# fa                 ...        7.800  7.8        1.0   112.000000          NaN
# fr                 ...        7.300  7.9        9.0   627.444444  1020.246430
# hi                 ...        6.250  7.0        4.0    16.250000    13.744696
# id                 ...        7.450  7.5        2.0   632.500000   597.505230
# it                 ...        8.100  8.1        1.0  2311.000000          NaN
# ja                 ...        7.800  8.3        5.0   977.600000  1627.559461
# ko                 ...        7.050  7.4        3.0  1249.000000  1392.913852
# nb                 ...        6.700  6.7        1.0   583.000000          NaN
# nl                 ...        6.800  6.8        1.0    66.000000          NaN
# no                 ...        6.100  6.1        1.0   311.000000          NaN
# pt                 ...        8.025  8.1        2.0  1159.000000   926.309883
# ru                 ...        6.400  6.4        1.0     7.000000          NaN
# th                 ...        6.000  6.0        1.0   152.000000          NaN
# zh                 ...        6.800  7.1        7.0   114.428571    85.111412
#
#
#                       min      25%     50%      75%      max
# original_language
# af                   94.0    94.00    94.0    94.00     94.0
# ar                   55.0    55.00    55.0    55.00     55.0
# cn                   57.0    57.00    57.0    57.00     57.0
# cs                    2.0     2.00     2.0     2.00      2.0
# de                   52.0   586.00   613.0   841.00   1037.0
# el                  332.0   332.00   332.0   332.00    332.0
# en                    0.0   220.00   648.0  1685.50  13752.0
# es                   28.0   101.00   308.0   489.00   3041.0
# fa                  112.0   112.00   112.0   112.00    112.0
# fr                   91.0   125.00   358.0   479.00   3310.0
# hi                    2.0     5.75    17.0    27.50     29.0
# id                  210.0   421.25   632.5   843.75   1055.0
# it                 2311.0  2311.00  2311.0  2311.00   2311.0
# ja                   31.0   107.00   137.0   773.00   3840.0
# ko                  356.0   446.50   537.0  1695.50   2854.0
# nb                  583.0   583.00   583.0   583.00    583.0
# nl                   66.0    66.00    66.0    66.00     66.0
# no                  311.0   311.00   311.0   311.00    311.0
# pt                  504.0   831.50  1159.0  1486.50   1814.0
# ru                    7.0     7.00     7.0     7.00      7.0
# th                  152.0   152.00   152.0   152.00    152.0
# zh                   29.0    46.50    65.0   204.00    206.0
#
# [22 rows x 48 columns]
